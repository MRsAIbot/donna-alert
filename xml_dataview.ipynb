# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path_to_csv = '../NapTAN/NapTANcsv/RailReferences.csv'
df = pd.read_csv(path_to_csv)
df
# Out:
#          AtcoCode TiplocCode CrsCode                             StationName  \
# 0      9100ABDARE     ABDARE     ABA                   Aberdare Rail Station
# 1        9100ABDO       ABDO     AUR                   Aberdour Rail Station
# 2       9100ABDVY      ABDVY     AVY                  Aberdovey Rail Station
# 3        9100ABER       ABER     ABE                       Aber Rail Station
# 4     9100ABGLELE    ABGLELE     AGL         Abergele & Pensarn Rail Station
# 5     9100ABRCYNS    ABRCYNS     ACY                  Abercynon Rail Station
# 6     9100ABRDEEN    ABRDEEN     ABD                   Aberdeen Rail Station
# 7        9100ABRE       ABRE     ABH                   Abererch Rail Station
# 8     9100ABRGVNY    ABRGVNY     AGV                Abergavenny Rail Station
# 9     9100ABRYSTH    ABRYSTH     AYW                Aberystwyth Rail Station
# 10       9100ABWD       ABWD     ABW        Abbey Wood (London) Rail Station
# ...

# %%
df['Waterloo' in df['StationName']].head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-6da50e6e659b> in <module>()
# ----> 1 df['Waterloo' in df['StationName']].head(10)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1778             return self._getitem_multilevel(key)
#    1779         else:
# -> 1780             return self._getitem_column(key)
#    1781
#    1782     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1785         # get column
#    1786         if self.columns.is_unique:
# -> 1787             return self._get_item_cache(key)
#    1788
#    1789         # duplicate columns & possible reduce dimensionaility
#
# /usr/local/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1056         res = cache.get(item)
# ...

# %%
[i for i in df['StationName']]
# Out:
# ['Aberdare Rail Station',
#  'Aberdour Rail Station',
#  'Aberdovey Rail Station',
#  'Aber Rail Station',
#  'Abergele & Pensarn Rail Station',
#  'Abercynon Rail Station',
#  'Aberdeen Rail Station',
#  'Abererch Rail Station',
#  'Abergavenny Rail Station',
#  'Aberystwyth Rail Station',
#  'Abbey Wood (London) Rail Station',
#  'Acton Bridge Rail Station',
#  'Achanalt Rail Station',
#  'Achnashellach Rail Station',
#  'Auchinleck Rail Station',
#  'Achnasheen Rail Station',
#  'Acklington Rail Station',
#  'Acle Rail Station',
#  'Acocks Green Rail Station',
#  'Accrington Rail Station',
#  'Acton Central Rail Station',
#  'Acton Main Line Rail Station',
#  'Adderley Park Rail Station',
#  'Addiewell Rail Station',
#  'Adisham Rail Station',
#  'Adlington (Cheshire) Rail Station',
#  'Addlestone Rail Station',
#  'Adlington (Lancs) Rail Station',
#  'Adwick Rail Station',
#  'Aughton Park Rail Station',
#  'Aigburth Rail Station',
#  'Ainsdale Rail Station',
# ...

# %%
df.dtypes
# Out:
# AtcoCode                 object
# TiplocCode               object
# CrsCode                  object
# StationName              object
# StationNameLang         float64
# GridType                 object
# Easting                   int64
# Northing                  int64
# CreationDateTime         object
# ModificationDateTime     object
# RevisionNumber            int64
# Modification             object
# dtype: object
